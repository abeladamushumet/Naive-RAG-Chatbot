# %%
# 1. Setup and Imports
import sys
sys.path.append(r'C:\Users\hp\Desktop\10 Acadamy\VS code\IntelligentComplaintAnalysisfor\Intelligent-Complaint-Analysis')

import pandas as pd
from scripts.data_processing import eda_utils as eda

# %%
# Load data
raw_data_path = r'C:\Users\hp\Desktop\10 Acadamy\VS code\IntelligentComplaintAnalysisfor\Intelligent-Complaint-Analysis\Data\raw\complaints.csv'
df = eda.load_data(raw_data_path)  
print(f"Shape: {df.shape}")
df.head()
# Out:
# C:\Users\hp\Desktop\10 Acadamy\VS code\IntelligentComplaintAnalysisfor\Intelligent-Complaint-Analysis\scripts\data_processing\eda_utils.py:18: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
# Shape: (9609797, 18)
#   Date received                                            Product  \
# 0    2025-06-20  Credit reporting or other personal consumer re...
# 1    2025-06-20                                    Debt collection
# 2    2025-06-20  Credit reporting or other personal consumer re...
# 3    2025-06-20  Credit reporting or other personal consumer re...
# 4    2025-06-20  Credit reporting or other personal consumer re...
#
#                Sub-product                                 Issue  \
# 0         Credit reporting  Incorrect information on your report
# 1  Telecommunications debt     Attempts to collect debt not owed
# 2         Credit reporting           Improper use of your report
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9609797 entries, 0 to 9609796
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %%
df.describe(include='all')
# Out:
#        Date received                                            Product  \
# count        9609797                                            9609797
# unique          4952                                                 21
# top       2025-01-17  Credit reporting or other personal consumer re...
# freq           34093                                            4834855
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#              Sub-product                                 Issue  \
# ...

# %%
# 3. Analyze Product Distribution
eda.plot_product_distribution(df)
# Out:
# C:\Users\hp\Desktop\10 Acadamy\VS code\IntelligentComplaintAnalysisfor\Intelligent-Complaint-Analysis\scripts\data_processing\eda_utils.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_counts.index, y=product_counts.values, palette="Blues_d")

# %%
# 4. Analyze Narrative Length Distribution
eda.plot_narrative_length_distribution(df)

# %%
# 5. Get Narrative Summary Statistics
stats = eda.get_narrative_stats(df)
for k, v in stats.items():
    print(f"{k}: {v}")
# Out:
# Total complaints: 9609797
# With narratives: 2980756
# Without narratives: 6629041
# Average word count: 175.59760074289878
# Max word count: 6469.0
# Min word count: 1.0

# %%
# 6. Filter Dataset by Product and Non-empty Narratives
valid_products = [
    "Credit card", 
    "Personal loan", 
    "Buy Now, Pay Later", 
    "Savings account", 
    "Money transfer, virtual currency"
]

filtered_df = eda.filter_valid_products(df, valid_products)
print(f"Filtered dataset size: {len(filtered_df):,}")
filtered_df.head(3)
# Out:
# Filtered dataset size: 80,667
#   Date received      Product                                 Sub-product  \
# 0    2025-06-13  Credit card                           Store credit card
# 1    2025-06-12  Credit card  General-purpose credit card or charge card
# 2    2025-06-12  Credit card  General-purpose credit card or charge card
#
#                                   Issue  \
# 0                 Getting a credit card
# 1    Other features, terms, or problems
# 2  Incorrect information on your report
#
#                                      Sub-issue  \
# 0  Card opened without my consent or knowledge
# 1                                Other problem
# 2                Account information incorrect
#
#                         Consumer complaint narrative  \
# 0  A XXXX XXXX card was opened under my name by a...
# 1  Dear CFPB, I have a secured credit card with c...
# 2  I have a Citi rewards cards. The credit balanc...
#
# ...

# %%
# 7. Save Filtered Dataset
processed_path = "../Data/processed/filtered_complaints.csv"
filtered_df.to_csv(processed_path, index=False)
print(f"Filtered complaints saved to {processed_path}")
# Out:
# Filtered complaints saved to ../Data/processed/filtered_complaints.csv
